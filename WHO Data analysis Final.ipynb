# %%
import pandas as pd # pandas 불러오기
from matplotlib import pyplot as plt # plt 불러오기

# %%
who = pd.read_csv("C:/Users/82107/Desktop/HUFS/3-1/데이터사이언스/기말 프로젝트/WHO_Life_Expectancy_2015.csv") # 2015년 WHO csv파일 불러오기
who.shape
# Out:
# (183, 23)

# %%
who.head()
# Out:
#                Country  Year      Status  Life expectancy   Adult Mortality  \
# 0          Afghanistan  2015  Developing              65.0              263
# 1              Albania  2015  Developing              77.8               74
# 2              Algeria  2015  Developing              75.6               19
# 3               Angola  2015  Developing              52.4              335
# 4  Antigua and Barbuda  2015  Developing              76.4               13
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1              0     4.60              364.975229         99.0         0  ...
# 2             21      NaN                0.000000         95.0        63  ...
# 3             66      NaN                0.000000         64.0       118  ...
# 4              0      NaN                0.000000         99.0         0  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS           GDP  Population  \
# 0               8.16           65        0.1    584.259210  33736494.0
# 1               6.00           99        0.1   3954.227830     28873.0
# 2                NaN           95        0.1   4132.762920  39871528.0
# 3                NaN           64        1.9   3695.793748   2785935.0
# 4                NaN           99        0.2  13566.954100     93566.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                    1.2                  1.3
# 2                    6.0                  5.8
# 3                    8.3                  8.2
# 4                    3.3                  3.3
#
#    Income composition of resources  Schooling     Density
# 0                            0.479       10.1   52.712071
# 1                            0.762       14.2  105.135146
# 2                            0.743       14.4   16.680246
# 3                            0.531       11.4   22.366553
# 4                            0.784       13.9  212.650000
#
# [5 rows x 23 columns]

# %%
print(who.info())   # 데이터 정보 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          183 non-null    object
#  1   Year                             183 non-null    int64
#  2   Status                           183 non-null    object
#  3   Life expectancy                  183 non-null    float64
#  4   Adult Mortality                  183 non-null    int64
#  5   infant deaths                    183 non-null    int64
#  6   Alcohol                          6 non-null      float64
#  7   percentage expenditure           183 non-null    float64
#  8   Hepatitis B                      174 non-null    float64
#  9   Measles                          183 non-null    int64
#  10   BMI                             181 non-null    float64
#  11  under-five deaths                183 non-null    int64
#  12  Polio                            183 non-null    int64
#  13  Total expenditure                2 non-null      float64
#  14  Diphtheria                       183 non-null    int64
#  15   HIV/AIDS                        183 non-null    float64
#  16  GDP                              160 non-null    float64
#  17  Population                       183 non-null    float64
#  18   thinness  1-19 years            181 non-null    float64
#  19   thinness 5-9 years              181 non-null    float64
#  20  Income composition of resources  173 non-null    float64
#  21  Schooling                        173 non-null    float64
#  22  Density                          183 non-null    float64
# dtypes: float64(14), int64(7), object(2)
# memory usage: 33.0+ KB
# None

# %%
# 변수 이름 정리하기
who.rename(columns = {" BMI " :"BMI", 
                                  "Life expectancy ": "Life_expectancy",
                                  "Adult Mortality":"Adult_mortality",
                                  "infant deaths":"Infant_deaths",
                                  "percentage expenditure":"Percentage_expenditure",
                                  "Hepatitis B":"HepatitisB",
                                  "Measles ":"Measles",
                                  "under-five deaths ": "Under_five_deaths",
                                  "Total expenditure":"Total_expenditure",
                                  "Diphtheria ": "Diphtheria",
                                  " thinness  1-19 years":"Thinness_1_to_19_years",
                                  " thinness 5-9 years":"Thinness_5_to_9_years",
                                  " HIV/AIDS":"HIV_AIDS",
                                  "Income composition of resources":"Income_composition_of_resources"}, inplace = True)

# %%
#구체적인 설명이 필요한  변수들

#Adult_Mortality: 1000명당 15-60세 사망자 수 
#Infant_deaths: 1000명당 영아 사망자 수
#Percentage_expenditure: 1인당 GDP 대비 보건 지출 비율
#Total_expenditure: 총 GDP 대비 보건 지출 비율
#HepatitisB: 1세 B형 간염 예방접종률 
#Under_five_deats: 1000명 당 5세 이하 사망자 수
#Polio: 1세 소아마이 예방접종률 
#Diphtheria: 1세 디프테리아 예방접종률
#HIV_AIDS: 0 - 4세 1000명당 HIV/AIDS 사망자 수 
#GDP: 1인당 GDP (미국 달러)
#Thinness_1_to_19_years: 10 - 19세 마름? 저체중? 빈약? 비율 %
#Thinness_5_to_9_years: 5 - 9세 위와 동일
#Income_composition_of_resources: UN HDI(인간개발지수) in terms of income composition of resources (index ranging from 0 to 1)??? 찾아보니 1인당 GNI가 주로 반영된 것 같네요... GNI는 국민들의 전반적인 소득수준을 파악하는 데 좋다고 합니다
#Schooling: 학교 교육 년수

# %%
# 국가 별 기대수명 시각화
LE_by_country = who.groupby('Country')['Life_expectancy'].mean().sort_values(ascending=True)
LE_by_country.plot(kind='bar', figsize=(70,15), fontsize=25)
plt.title("Life_Expectancy - Country",fontsize=40)
plt.xlabel("Country",fontsize=35)
plt.ylabel("Avg Life_Expectancy",fontsize=35)
plt.show()

# %%
who = who.drop(['Year'], axis=1) # 불필요한 연도, 국가 변수 제거
who = who.drop(['Country'], axis = 1)

# %%
who.describe() # 결측 제거 전 통계량 확인
# Out:
#        Life_expectancy  Adult_mortality  Infant_deaths    Alcohol  \
# count       183.000000       183.000000     183.000000   6.000000
# mean         71.616940       152.863388      23.803279   5.288333
# std           8.123706        97.561184      83.683762   4.038115
# min          51.000000         1.000000       0.000000   0.010000
# 25%          65.750000        74.000000       0.000000   2.492500
# 50%          73.900000       138.000000       2.000000   5.285000
# 75%          76.950000       213.000000      17.000000   8.017500
# max          88.000000       484.000000     910.000000  10.660000
#
#        Percentage_expenditure  HepatitisB       Measles         BMI  \
# count              183.000000  174.000000    183.000000  181.000000
# mean                 2.383906   82.425287   1502.901639   42.754144
# std                 27.461032   24.008492   7842.394928   20.685702
# min                  0.000000    6.000000      0.000000    2.500000
# 25%                  0.000000   78.750000      0.000000   24.300000
# 50%                  0.000000   93.000000     17.000000   48.600000
# 75%                  0.000000   97.000000    202.000000   61.400000
# max                364.975229   99.000000  90387.000000   77.600000
#
#        Under_five_deaths       Polio  Total_expenditure  Diphtheria  \
# count         183.000000  183.000000           2.000000  183.000000
# mean           31.612022   83.207650           7.080000   84.633880
# std           107.779778   24.245778           1.527351   22.162793
# min             0.000000    5.000000           6.000000    6.000000
# 25%             0.000000   83.000000           6.540000   83.500000
# 50%             3.000000   93.000000           7.080000   93.000000
# 75%            21.000000   97.000000           7.620000   97.000000
# max          1100.000000   99.000000           8.160000   99.000000
#
#          HIV_AIDS           GDP    Population  Thinness_1_to_19_years  \
# count  183.000000    160.000000  1.830000e+02              181.000000
# mean     0.660656   8142.194306  1.431730e+07                4.534807
# std      1.344702  12769.593873  3.641957e+07                4.099425
# min      0.100000     33.681223  2.966000e+03                0.100000
# 25%      0.100000    782.273120  3.564730e+05                1.500000
# 50%      0.100000   3515.980304  3.431552e+06                3.500000
# 75%      0.400000   8853.934073  1.145187e+07                6.500000
# max      9.300000  66346.522670  3.214188e+08               26.700000
#
#        Thinness_5_to_9_years  Income_composition_of_resources   Schooling  \
# count             181.000000                       173.000000  173.000000
# mean                4.575691                         0.691740   12.927168
# std                 4.180785                         0.153412    2.912366
# min                 0.100000                         0.347000    4.900000
# 25%                 1.500000                         0.565000   10.800000
# 50%                 3.400000                         0.723000   13.100000
# 75%                 6.400000                         0.798000   15.000000
# max                27.300000                         0.948000   20.400000
#
#            Density
# count   183.000000
# mean    197.853279
# std     618.502182
# min       1.925464
# 25%      31.443366
# 50%      80.665043
# 75%     183.033755
# max    7806.772920

# %%
who.nunique()  # 항목 별 unique한 요소의 개수
# Out:
# Status                               2
# Life_expectancy                    132
# Adult_mortality                    130
# Infant_deaths                       52
# Alcohol                              6
# Percentage_expenditure               3
# HepatitisB                          44
# Measles                             98
# BMI                                141
# Under_five_deaths                   54
# Polio                               42
# Total_expenditure                    2
# Diphtheria                          43
# HIV_AIDS                            33
# GDP                                160
# Population                         183
# Thinness_1_to_19_years              77
# Thinness_5_to_9_years               85
# Income_composition_of_resources    148
# Schooling                           89
# Density                            183
# dtype: int64

# %%
who['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
status_aliases = {'Developing':0, 'Developed':1} # 분석을 위해 'Status' 항목을 수치형 항목으로 변환

who['Status'] = who['Status'].apply(lambda v: status_aliases.get(v,v))

# %%
who.isnull().sum() # 항목별 결측 확인
# Out:
# Status                               0
# Life_expectancy                      0
# Adult_mortality                      0
# Infant_deaths                        0
# Alcohol                            177
# Percentage_expenditure               0
# HepatitisB                           9
# Measles                              0
# BMI                                  2
# Under_five_deaths                    0
# Polio                                0
# Total_expenditure                  181
# Diphtheria                           0
# HIV_AIDS                             0
# GDP                                 23
# Population                           0
# Thinness_1_to_19_years               2
# Thinness_5_to_9_years                2
# Income_composition_of_resources     10
# Schooling                           10
# Density                              0
# dtype: int64

# %%
who = who.drop(['Alcohol', 'Total_expenditure'], axis=1) #  Alcohol과 Total_expenditure 변수의 결측이 너무 많으므로 제거.

# %%
who['Percentage_expenditure'] # Percentage_expenditure 변수 확인; 대부분 값이 0이여서 삭제하는 것이 좋아보입니다.
# Out:
# 0       71.279624
# 1      364.975229
# 2        0.000000
# 3        0.000000
# 4        0.000000
#           ...
# 178      0.000000
# 179      0.000000
# 180      0.000000
# 181      0.000000
# 182      0.000000
# Name: Percentage_expenditure, Length: 183, dtype: float64

# %%
who = who.drop(['Percentage_expenditure'], axis=1) # Percentage_expenditure 삭제

# %%
who.corr() # 결측 제거 전 상관계수
# Out:
#                                    Status  Life_expectancy  Adult_mortality  \
# Status                           1.000000         0.516657        -0.369002
# Life_expectancy                  0.516657         1.000000        -0.779119
# Adult_mortality                 -0.369002        -0.779119         1.000000
# Infant_deaths                   -0.124752        -0.241290         0.188205
# HepatitisB                       0.122388         0.420848        -0.231715
# Measles                         -0.081324        -0.074617         0.051196
# BMI                              0.292940         0.516663        -0.369920
# Under_five_deaths               -0.129101        -0.271921         0.212004
# Polio                            0.225702         0.515602        -0.372392
# Diphtheria                       0.221115         0.500300        -0.322688
# HIV_AIDS                        -0.192463        -0.608345         0.621012
# GDP                              0.410997         0.470440        -0.362322
# Population                       0.095434         0.022011        -0.030162
# Thinness_1_to_19_years          -0.371305        -0.475020         0.298016
# Thinness_5_to_9_years           -0.375223        -0.475027         0.302699
# Income_composition_of_resources  0.558068         0.907364        -0.657258
# Schooling                        0.557994         0.818159        -0.546178
# Density                          0.184630         0.170742        -0.157340
#
#                                  Infant_deaths  HepatitisB   Measles  \
# Status                               -0.124752    0.122388 -0.081324
# Life_expectancy                      -0.241290    0.420848 -0.074617
# Adult_mortality                       0.188205   -0.231715  0.051196
# Infant_deaths                         1.000000   -0.086902  0.800859
# HepatitisB                           -0.086902    1.000000  0.015642
# Measles                               0.800859    0.015642  1.000000
# BMI                                  -0.223562    0.179551 -0.128184
# Under_five_deaths                     0.994196   -0.104716  0.764908
# Polio                                -0.129729    0.594559 -0.028342
# Diphtheria                           -0.117989    0.915220 -0.001623
# HIV_AIDS                              0.095837   -0.383792 -0.026580
# GDP                                  -0.122934    0.161423 -0.082470
# Population                            0.220640    0.003804  0.084750
# Thinness_1_to_19_years                0.530544   -0.057951  0.343274
# Thinness_5_to_9_years                 0.530548   -0.099965  0.338294
# Income_composition_of_resources      -0.207522    0.327169 -0.074674
# Schooling                            -0.208149    0.334051 -0.067796
# Density                               0.005460    0.100551  0.003339
#
#                                       BMI  Under_five_deaths     Polio  \
# Status                           0.292940          -0.129101  0.225702
# Life_expectancy                  0.516663          -0.271921  0.515602
# Adult_mortality                 -0.369920           0.212004 -0.372392
# Infant_deaths                   -0.223562           0.994196 -0.129729
# HepatitisB                       0.179551          -0.104716  0.594559
# Measles                         -0.128184           0.764908 -0.028342
# BMI                              1.000000          -0.234982  0.212450
# Under_five_deaths               -0.234982           1.000000 -0.147457
# Polio                            0.212450          -0.147457  1.000000
# Diphtheria                       0.197686          -0.137863  0.661635
# HIV_AIDS                        -0.292453           0.122604 -0.403233
# GDP                              0.372604          -0.129160  0.253588
# Population                       0.050677           0.244296 -0.117357
# Thinness_1_to_19_years          -0.472508           0.522142 -0.194518
# Thinness_5_to_9_years           -0.489716           0.521006 -0.196669
# Income_composition_of_resources  0.589784          -0.229571  0.464525
# Schooling                        0.566204          -0.227530  0.408363
# Density                         -0.019072           0.001549  0.099710
#
#                                  Diphtheria  HIV_AIDS       GDP  Population  \
# Status                             0.221115 -0.192463  0.410997    0.095434
# Life_expectancy                    0.500300 -0.608345  0.470440    0.022011
# Adult_mortality                   -0.322688  0.621012 -0.362322   -0.030162
# Infant_deaths                     -0.117989  0.095837 -0.122934    0.220640
# HepatitisB                         0.915220 -0.383792  0.161423    0.003804
# Measles                           -0.001623 -0.026580 -0.082470    0.084750
# BMI                                0.197686 -0.292453  0.372604    0.050677
# Under_five_deaths                 -0.137863  0.122604 -0.129160    0.244296
# Polio                              0.661635 -0.403233  0.253588   -0.117357
# Diphtheria                         1.000000 -0.441413  0.241453   -0.000840
# HIV_AIDS                          -0.441413  1.000000 -0.208235   -0.010861
# GDP                                0.241453 -0.208235  1.000000    0.249398
# Population                        -0.000840 -0.010861  0.249398    1.000000
# Thinness_1_to_19_years            -0.113999  0.184290 -0.272461    0.006113
# Thinness_5_to_9_years             -0.157038  0.168471 -0.282821   -0.002522
# Income_composition_of_resources    0.431936 -0.478788  0.523652    0.000360
# Schooling                          0.410833 -0.394161  0.440314    0.019380
# Density                            0.096429 -0.086623  0.324107   -0.037894
#
#                                  Thinness_1_to_19_years  \
# Status                                        -0.371305
# Life_expectancy                               -0.475020
# Adult_mortality                                0.298016
# Infant_deaths                                  0.530544
# HepatitisB                                    -0.057951
# Measles                                        0.343274
# BMI                                           -0.472508
# Under_five_deaths                              0.522142
# Polio                                         -0.194518
# Diphtheria                                    -0.113999
# HIV_AIDS                                       0.184290
# GDP                                           -0.272461
# Population                                     0.006113
# Thinness_1_to_19_years                         1.000000
# Thinness_5_to_9_years                          0.973195
# Income_composition_of_resources               -0.507868
# Schooling                                     -0.507250
# Density                                        0.027444
#
#                                  Thinness_5_to_9_years  \
# Status                                       -0.375223
# Life_expectancy                              -0.475027
# Adult_mortality                               0.302699
# Infant_deaths                                 0.530548
# HepatitisB                                   -0.099965
# Measles                                       0.338294
# BMI                                          -0.489716
# Under_five_deaths                             0.521006
# Polio                                        -0.196669
# Diphtheria                                   -0.157038
# HIV_AIDS                                      0.168471
# GDP                                          -0.282821
# Population                                   -0.002522
# Thinness_1_to_19_years                        0.973195
# Thinness_5_to_9_years                         1.000000
# Income_composition_of_resources              -0.505994
# Schooling                                    -0.503879
# Density                                       0.029831
#
#                                  Income_composition_of_resources  Schooling  \
# Status                                                  0.558068   0.557994
# Life_expectancy                                         0.907364   0.818159
# Adult_mortality                                        -0.657258  -0.546178
# Infant_deaths                                          -0.207522  -0.208149
# HepatitisB                                              0.327169   0.334051
# Measles                                                -0.074674  -0.067796
# BMI                                                     0.589784   0.566204
# Under_five_deaths                                      -0.229571  -0.227530
# Polio                                                   0.464525   0.408363
# Diphtheria                                              0.431936   0.410833
# HIV_AIDS                                               -0.478788  -0.394161
# GDP                                                     0.523652   0.440314
# Population                                              0.000360   0.019380
# Thinness_1_to_19_years                                 -0.507868  -0.507250
# Thinness_5_to_9_years                                  -0.505994  -0.503879
# Income_composition_of_resources                         1.000000   0.917514
# Schooling                                               0.917514   1.000000
# Density                                                 0.153161   0.090260
#
#                                   Density
# Status                           0.184630
# Life_expectancy                  0.170742
# Adult_mortality                 -0.157340
# Infant_deaths                    0.005460
# HepatitisB                       0.100551
# Measles                          0.003339
# BMI                             -0.019072
# Under_five_deaths                0.001549
# Polio                            0.099710
# Diphtheria                       0.096429
# HIV_AIDS                        -0.086623
# GDP                              0.324107
# Population                      -0.037894
# Thinness_1_to_19_years           0.027444
# Thinness_5_to_9_years            0.029831
# Income_composition_of_resources  0.153161
# Schooling                        0.090260
# Density                          1.000000

# %%
who.isnull().sum()
# Out:
# Status                              0
# Life_expectancy                     0
# Adult_mortality                     0
# Infant_deaths                       0
# HepatitisB                          9
# Measles                             0
# BMI                                 2
# Under_five_deaths                   0
# Polio                               0
# Diphtheria                          0
# HIV_AIDS                            0
# GDP                                23
# Population                          0
# Thinness_1_to_19_years              2
# Thinness_5_to_9_years               2
# Income_composition_of_resources    10
# Schooling                          10
# Density                             0
# dtype: int64

# %%
# 결측 평균으로 채우기

who['HepatitisB'] = who['HepatitisB'].fillna(who['HepatitisB'].mean())
who['BMI'] = who['BMI'].fillna(who['BMI'].mean())
who['GDP'] = who['GDP'].fillna(who['GDP'].mean())
who['Thinness_1_to_19_years'] = who['Thinness_1_to_19_years'].fillna(who['Thinness_1_to_19_years'].mean())
who['Thinness_5_to_9_years'] = who['Thinness_5_to_9_years'].fillna(who['Thinness_5_to_9_years'].mean())
who['Income_composition_of_resources'] = who['Income_composition_of_resources'].fillna(who['Income_composition_of_resources'].mean())
who['Schooling'] = who['Schooling'].fillna(who['Schooling'].mean())

# %%
who.isnull().sum()
# Out:
# Status                             0
# Life_expectancy                    0
# Adult_mortality                    0
# Infant_deaths                      0
# HepatitisB                         0
# Measles                            0
# BMI                                0
# Under_five_deaths                  0
# Polio                              0
# Diphtheria                         0
# HIV_AIDS                           0
# GDP                                0
# Population                         0
# Thinness_1_to_19_years             0
# Thinness_5_to_9_years              0
# Income_composition_of_resources    0
# Schooling                          0
# Density                            0
# dtype: int64

# %%
who.describe() # 결측 처리 후 통계량 확인
# Out:
#            Status  Life_expectancy  Adult_mortality  Infant_deaths  \
# count  183.000000       183.000000       183.000000     183.000000
# mean     0.174863        71.616940       152.863388      23.803279
# std      0.380892         8.123706        97.561184      83.683762
# min      0.000000        51.000000         1.000000       0.000000
# 25%      0.000000        65.750000        74.000000       0.000000
# 50%      0.000000        73.900000       138.000000       2.000000
# 75%      0.000000        76.950000       213.000000      17.000000
# max      1.000000        88.000000       484.000000     910.000000
#
#        HepatitisB       Measles         BMI  Under_five_deaths       Polio  \
# count  183.000000    183.000000  183.000000         183.000000  183.000000
# mean    82.425287   1502.901639   42.754144          31.612022   83.207650
# std     23.407349   7842.394928   20.571730         107.779778   24.245778
# min      6.000000      0.000000    2.500000           0.000000    5.000000
# 25%     81.000000      0.000000   24.300000           0.000000   83.000000
# 50%     92.000000     17.000000   48.600000           3.000000   93.000000
# 75%     97.000000    202.000000   61.350000          21.000000   97.000000
# max     99.000000  90387.000000   77.600000        1100.000000   99.000000
#
#        Diphtheria    HIV_AIDS           GDP    Population  \
# count  183.000000  183.000000    183.000000  1.830000e+02
# mean    84.633880    0.660656   8142.194306  1.431730e+07
# std     22.162793    1.344702  11935.481755  3.641957e+07
# min      6.000000    0.100000     33.681223  2.966000e+03
# 25%     83.500000    0.100000   1152.309599  3.564730e+05
# 50%     93.000000    0.100000   4132.762920  3.431552e+06
# 75%     97.000000    0.400000   8142.194306  1.145187e+07
# max     99.000000    9.300000  66346.522670  3.214188e+08
#
#        Thinness_1_to_19_years  Thinness_5_to_9_years  \
# count              183.000000             183.000000
# mean                 4.534807               4.575691
# std                  4.076838               4.157750
# min                  0.100000               0.100000
# 25%                  1.500000               1.500000
# 50%                  3.500000               3.400000
# 75%                  6.500000               6.400000
# max                 26.700000              27.300000
#
#        Income_composition_of_resources   Schooling      Density
# count                       183.000000  183.000000   183.000000
# mean                          0.691740   12.927168   197.853279
# std                           0.149138    2.831225   618.502182
# min                           0.347000    4.900000     1.925464
# 25%                           0.575500   11.100000    31.443366
# 50%                           0.718000   12.927168    80.665043
# 75%                           0.794500   14.850000   183.033755
# max                           0.948000   20.400000  7806.772920

# %%
who.corr()  # 결측 처리 후 항목 별 상관계수
# Out:
#                                    Status  Life_expectancy  Adult_mortality  \
# Status                           1.000000         0.516657        -0.369002
# Life_expectancy                  0.516657         1.000000        -0.779119
# Adult_mortality                 -0.369002        -0.779119         1.000000
# Infant_deaths                   -0.124752        -0.241290         0.188205
# HepatitisB                       0.108337         0.398488        -0.227031
# Measles                         -0.081324        -0.074617         0.051196
# BMI                              0.292597         0.510951        -0.365879
# Under_five_deaths               -0.129101        -0.271921         0.212004
# Polio                            0.225702         0.515602        -0.372392
# Diphtheria                       0.221115         0.500300        -0.322688
# HIV_AIDS                        -0.192463        -0.608345         0.621012
# GDP                              0.404688         0.446820        -0.341132
# Population                       0.095434         0.022011        -0.030162
# Thinness_1_to_19_years          -0.370870        -0.469768         0.294761
# Thinness_5_to_9_years           -0.374784        -0.469775         0.299392
# Income_composition_of_resources  0.533588         0.861431        -0.627878
# Schooling                        0.533518         0.776743        -0.521763
# Density                          0.184630         0.170742        -0.157340
#
#                                  Infant_deaths  HepatitisB   Measles  \
# Status                               -0.124752    0.108337 -0.081324
# Life_expectancy                      -0.241290    0.398488 -0.074617
# Adult_mortality                       0.188205   -0.227031  0.051196
# Infant_deaths                         1.000000   -0.086727  0.800859
# HepatitisB                           -0.086727    1.000000  0.015627
# Measles                               0.800859    0.015627  1.000000
# BMI                                  -0.223459    0.171990 -0.128157
# Under_five_deaths                     0.994196   -0.104492  0.764908
# Polio                                -0.129729    0.590183 -0.028342
# Diphtheria                           -0.117989    0.909236 -0.001623
# HIV_AIDS                              0.095837   -0.382053 -0.026580
# GDP                                  -0.120144    0.146708 -0.081242
# Population                            0.220640    0.003774  0.084750
# Thinness_1_to_19_years                0.530298   -0.055650  0.343201
# Thinness_5_to_9_years                 0.530302   -0.096178  0.338223
# Income_composition_of_resources      -0.203145    0.307283 -0.074456
# Schooling                            -0.203758    0.311093 -0.067598
# Density                               0.005460    0.100441  0.003339
#
#                                       BMI  Under_five_deaths     Polio  \
# Status                           0.292597          -0.129101  0.225702
# Life_expectancy                  0.510951          -0.271921  0.515602
# Adult_mortality                 -0.365879           0.212004 -0.372392
# Infant_deaths                   -0.223459           0.994196 -0.129729
# HepatitisB                       0.171990          -0.104492  0.590183
# Measles                         -0.128157           0.764908 -0.028342
# BMI                              1.000000          -0.234819  0.210572
# Under_five_deaths               -0.234819           1.000000 -0.147457
# Polio                            0.210572          -0.147457  1.000000
# Diphtheria                       0.194388          -0.137863  0.661635
# HIV_AIDS                        -0.289027           0.122604 -0.403233
# GDP                              0.353726          -0.126107  0.235286
# Population                       0.050665           0.244296 -0.117357
# Thinness_1_to_19_years          -0.472508           0.521780 -0.192798
# Thinness_5_to_9_years           -0.489716           0.520645 -0.194931
# Income_composition_of_resources  0.567824          -0.224444  0.459159
# Schooling                        0.534174          -0.222449  0.403647
# Density                         -0.019063           0.001549  0.099710
#
#                                  Diphtheria  HIV_AIDS       GDP  Population  \
# Status                             0.221115 -0.192463  0.404688    0.095434
# Life_expectancy                    0.500300 -0.608345  0.446820    0.022011
# Adult_mortality                   -0.322688  0.621012 -0.341132   -0.030162
# Infant_deaths                     -0.117989  0.095837 -0.120144    0.220640
# HepatitisB                         0.909236 -0.382053  0.146708    0.003774
# Measles                           -0.001623 -0.026580 -0.081242    0.084750
# BMI                                0.194388 -0.289027  0.353726    0.050665
# Under_five_deaths                 -0.137863  0.122604 -0.126107    0.244296
# Polio                              0.661635 -0.403233  0.235286   -0.117357
# Diphtheria                         1.000000 -0.441413  0.227161   -0.000840
# HIV_AIDS                          -0.441413  1.000000 -0.204076   -0.010861
# GDP                                0.227161 -0.204076  1.000000    0.237849
# Population                        -0.000840 -0.010861  0.237849    1.000000
# Thinness_1_to_19_years            -0.112097  0.182131 -0.256302    0.006111
# Thinness_5_to_9_years             -0.154418  0.166497 -0.266963   -0.002522
# Income_composition_of_resources    0.425316 -0.475747  0.459148    0.000271
# Schooling                          0.404536 -0.391657  0.379753    0.014600
# Density                            0.096429 -0.086623  0.323033   -0.037894
#
#                                  Thinness_1_to_19_years  \
# Status                                        -0.370870
# Life_expectancy                               -0.469768
# Adult_mortality                                0.294761
# Infant_deaths                                  0.530298
# HepatitisB                                    -0.055650
# Measles                                        0.343201
# BMI                                           -0.472508
# Under_five_deaths                              0.521780
# Polio                                         -0.192798
# Diphtheria                                    -0.112097
# HIV_AIDS                                       0.182131
# GDP                                           -0.256302
# Population                                     0.006111
# Thinness_1_to_19_years                         1.000000
# Thinness_5_to_9_years                          0.973195
# Income_composition_of_resources               -0.493523
# Schooling                                     -0.482935
# Density                                        0.027431
#
#                                  Thinness_5_to_9_years  \
# Status                                       -0.374784
# Life_expectancy                              -0.469775
# Adult_mortality                               0.299392
# Infant_deaths                                 0.530302
# HepatitisB                                   -0.096178
# Measles                                       0.338223
# BMI                                          -0.489716
# Under_five_deaths                             0.520645
# Polio                                        -0.194931
# Diphtheria                                   -0.154418
# HIV_AIDS                                      0.166497
# GDP                                          -0.266963
# Population                                   -0.002522
# Thinness_1_to_19_years                        0.973195
# Thinness_5_to_9_years                         1.000000
# Income_composition_of_resources              -0.491680
# Schooling                                    -0.479680
# Density                                       0.029817
#
#                                  Income_composition_of_resources  Schooling  \
# Status                                                  0.533588   0.533518
# Life_expectancy                                         0.861431   0.776743
# Adult_mortality                                        -0.627878  -0.521763
# Infant_deaths                                          -0.203145  -0.203758
# HepatitisB                                              0.307283   0.311093
# Measles                                                -0.074456  -0.067598
# BMI                                                     0.567824   0.534174
# Under_five_deaths                                      -0.224444  -0.222449
# Polio                                                   0.459159   0.403647
# Diphtheria                                              0.425316   0.404536
# HIV_AIDS                                               -0.475747  -0.391657
# GDP                                                     0.459148   0.379753
# Population                                              0.000271   0.014600
# Thinness_1_to_19_years                                 -0.493523  -0.482935
# Thinness_5_to_9_years                                  -0.491680  -0.479680
# Income_composition_of_resources                         1.000000   0.917514
# Schooling                                               0.917514   1.000000
# Density                                                 0.152890   0.090101
#
#                                   Density
# Status                           0.184630
# Life_expectancy                  0.170742
# Adult_mortality                 -0.157340
# Infant_deaths                    0.005460
# HepatitisB                       0.100441
# Measles                          0.003339
# BMI                             -0.019063
# Under_five_deaths                0.001549
# Polio                            0.099710
# Diphtheria                       0.096429
# HIV_AIDS                        -0.086623
# GDP                              0.323033
# Population                      -0.037894
# Thinness_1_to_19_years           0.027431
# Thinness_5_to_9_years            0.029817
# Income_composition_of_resources  0.152890
# Schooling                        0.090101
# Density                          1.000000

# %%
from sklearn.linear_model import LinearRegression # sklearn 라이브러리를 이용한 선형회귀분석
from sklearn.model_selection import train_test_split # 데이터셋 분리 작업

# %%
Y = who['Life_expectancy']
X = who.drop(['Life_expectancy'], axis = 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((146, 17), (37, 17), (146,), (37,))

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lm.predict(X_test)

# %%
import numpy as np
coef = pd.Series(data = np.round(lm.coef_,3), index = X.columns)
coef #선형회귀 방정식은 다음과 같은 계수를 가진다
# 결과가 이상하다. 위에서 살펴본 상관계수와는 다른 결과가 나온다
# Out:
# Status                              2.094
# Adult_mortality                    -0.026
# Infant_deaths                       0.336
# HepatitisB                          0.035
# Measles                            -0.000
# BMI                                -0.007
# Under_five_deaths                  -0.271
# Polio                               0.020
# Diphtheria                          0.006
# HIV_AIDS                           -0.597
# GDP                                 0.000
# Population                          0.000
# Thinness_1_to_19_years             -0.120
# Thinness_5_to_9_years               0.009
# Income_composition_of_resources    22.181
# Schooling                           0.051
# Density                             0.000
# dtype: float64

# %%
intercept = np.round(lm.intercept_,2) # intercept는 다음과 같다.
intercept
# Out:
# 55.64

# %%
from sklearn.metrics import mean_squared_error, r2_score # # MSE(mean squared erroe), R-square (모형 성능 확인)

# %%
# MSE 와 R-square 방법을 통해 정확도 평가 ; MSE, R-sqaure 모두 값이 현저히 낮다

mse = mean_squared_error(Y_test, Y_predict)  
rmse = np.sqrt(mse)
r_square = r2_score(Y_test, Y_predict)
print('MSE : {0:.3f}, RMSE : {1:.3f}'.format(mse, rmse))
print('R-square : {0:.3f}'.format(r_square))
# Out:
# MSE : 47.815, RMSE : 6.915
# R-square : 0.292

# %%
# 기대수명과 나머지 변수 간 관계에 대한 산점도와 선형 회귀 그래프 (시각화)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axs = plt.subplots(figsize = (16, 30), ncols = 3, nrows = 6)
x_features = [ 'Status', 'Adult_mortality', 'Infant_deaths', 'HepatitisB', 'Measles', 'BMI', 'Under_five_deaths', 'Polio', 'Diphtheria', 'HIV_AIDS', 'GDP', 'Population', 'Thinness_1_to_19_years', 'Thinness_5_to_9_years', 'Income_composition_of_resources', 'Schooling', 'Density']
plot_color = ['r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g']
for i, feature in enumerate(x_features):
    row = int(i/3)
    col = i%3
    sns.regplot(x = feature, y = 'Life_expectancy', data = who, ax = axs[row][col], color = plot_color[i])

# %%
# 다중공선성 확인을 위해 위의 그래프에서 상관관계가 의심되는 3개를 추출 및 시각화 해서 산점도로 살피기 ; 
# Schooling과 ICOR는 양의 상관관계가 있고, 각각은 Adult_Mortality 와 음의 상관관계가 있어보인다.

plt.figure(figsize=(20,8))

plt.subplot(1,3,1)
plt.scatter(who["Schooling"], who["Adult_mortality"])
plt.title("Schooling vs Adult_mortality")

plt.subplot(1,3,2)
plt.scatter(who["Schooling"], who["Income_composition_of_resources"])
plt.title("Schooling vs Income_composition_of_resources")

plt.subplot(1,3,3)
plt.scatter(who["Adult_mortality"], who["Income_composition_of_resources"])
plt.title("Adult_mortality vs Income_composition_of_resources")

plt.show()

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor # VIF 확인을 위한 라이브러리 불러오기

# %%
rm_Life_expectancy = 'Life_expectancy ~ Status + Adult_mortality + Infant_deaths + HepatitisB + Measles + BMI + Under_five_deaths + Polio + Diphtheria + HIV_AIDS + GDP + Population + Thinness_1_to_19_years + Thinness_5_to_9_years +  Income_composition_of_resources + Schooling + Density'
rm_Life_expectancy_ols = ols(rm_Life_expectancy, data = who)
rm_Life_expectancy_result = rm_Life_expectancy_ols.fit()

pd.DataFrame({'Features': column, 'VIF': variance_inflation_factor(rm_Life_expectancy_ols.exog, i)} 
             for i, column in enumerate(rm_Life_expectancy_ols.exog_names)
             if column != 'Intercept')  

# 독립변수 별 VIF 값. 
# 일반적으로 10 이상이면 서로 강한 상관관계를 가진다고 한다.
# Infant_deaths 와 Under_five_deaths가 비슷하다. 생각해보니 둘이 거의 비슷한 내용을 담고 있을 듯 하다
# Thinness_1_to_19_years와 Thinness_5_to_9_years 역시 VIF 값이 비슷하고, 생각해보니 이번에는 아예 한쪽(1-19세)이 다른 쪽(5-9세)을 포함하고 있었다
# Income_composition_of_resources와 Schooling은 10을 넘지는 않지만 높고, 서로 값이 비슷하면서 위의 분석결과 회귀계수가 이상하게 나오므로 고려.
# Out:
#                            Features         VIF
# 0                            Status    1.633846
# 1                   Adult_mortality    2.308682
# 2                     Infant_deaths  156.200484
# 3                        HepatitisB    6.521595
# 4                           Measles    4.013301
# 5                               BMI    1.760265
# 6                 Under_five_deaths  134.248748
# 7                             Polio    2.045463
# 8                        Diphtheria    7.857259
# 9                          HIV_AIDS    1.958979
# 10                              GDP    1.668087
# 11                       Population    1.330827
# 12           Thinness_1_to_19_years   21.347986
# 13            Thinness_5_to_9_years   21.679630
# 14  Income_composition_of_resources    9.590918
# 15                        Schooling    7.187692
# 16                          Density    1.228202

# %%
# VIF를 참고하여 Infant_deaths, Thinness_5_to_9_years, Schooling을 제거하고 다시 회귀분석을 진행

# %%
# csv 파일 다시 불러오기
who = pd.read_csv("C:/Users/82107/Desktop/HUFS/3-1/데이터사이언스/기말 프로젝트/WHO_Life_Expectancy_2015.csv")

# %%
# 변수 이름 정리하기
who.rename(columns = {" BMI " :"BMI", 
                                  "Life expectancy ": "Life_expectancy",
                                  "Adult Mortality":"Adult_mortality",
                                  "infant deaths":"Infant_deaths",
                                  "percentage expenditure":"Percentage_expenditure",
                                  "Hepatitis B":"HepatitisB",
                                  "Measles ":"Measles",
                                  "under-five deaths ": "Under_five_deaths",
                                  "Total expenditure":"Total_expenditure",
                                  "Diphtheria ": "Diphtheria",
                                  " thinness  1-19 years":"Thinness_1_to_19_years",
                                  " thinness 5-9 years":"Thinness_5_to_9_years",
                                  " HIV/AIDS":"HIV_AIDS",
                                  "Income composition of resources":"Income_composition_of_resources"}, inplace = True)

# %%
who = who.drop(['Year'], axis=1) # 불필요한 연도, 국가 변수 제거
who = who.drop(['Country'], axis = 1)

# %%
status_aliases = {'Developing':0, 'Developed':1} # 'Status' 항목을 수치형 항목으로 변환

who['Status'] = who['Status'].apply(lambda v: status_aliases.get(v,v))

# %%
who = who.drop(['Alcohol', 'Total_expenditure'], axis=1) #  Alcohol과 Total_expenditure 변수의 결측이 너무 많으므로 제거.

# %%
who = who.drop(['Percentage_expenditure'], axis=1) # Percentage_expenditure 삭제

# 다중공선성 해결을 위해 drop 
who = who.drop(['Infant_deaths'], axis=1)
who = who.drop(['Thinness_5_to_9_years'], axis=1)
who = who.drop(['Schooling'], axis=1)

# %%
# 결측 평균으로 채우기

who['HepatitisB'] = who['HepatitisB'].fillna(who['HepatitisB'].mean())
who['BMI'] = who['BMI'].fillna(who['BMI'].mean())
who['GDP'] = who['GDP'].fillna(who['GDP'].mean())
who['Thinness_1_to_19_years'] = who['Thinness_1_to_19_years'].fillna(who['Thinness_1_to_19_years'].mean())
who['Income_composition_of_resources'] = who['Income_composition_of_resources'].fillna(who['Income_composition_of_resources'].mean())

# %%
# 데이터들의 극단치 제거

who=who.loc[who["Population"]<1093859294]
who=who.loc[who['Measles']<=2000]
who=who.loc[who['Under_five_deaths']<200]
who=who.loc[who['GDP']<20000]
who=who.loc[who['Density']<1500]

# %%
from sklearn.linear_model import LinearRegression # sklearn 라이브러리를 이용한 선형회귀분석
from sklearn.model_selection import train_test_split # 데이터셋 분리 작업

# %%
Y = who['Life_expectancy']
X = who.drop(['Life_expectancy'], axis = 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((120, 14), (31, 14), (120,), (31,))

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lm.predict(X_test)

# %%
import numpy as np
coef = pd.Series(data = np.round(lm.coef_,3), index = X.columns)
coef #선형회귀 방정식은 다음과 같은 계수를 가진다

# Status, HIV_AIDS, ICOR의 회귀계수가 높다.
# Out:
# Status                              1.181
# Adult_mortality                    -0.019
# HepatitisB                          0.043
# Measles                             0.000
# BMI                                -0.015
# Under_five_deaths                  -0.048
# Polio                               0.005
# Diphtheria                         -0.023
# HIV_AIDS                           -0.457
# GDP                                -0.000
# Population                          0.000
# Thinness_1_to_19_years             -0.146
# Income_composition_of_resources    32.310
# Density                            -0.001
# dtype: float64

# %%
intercept = np.round(lm.intercept_,2) # intercept는 다음과 같다.
intercept
# Out:
# 52.26

# %%
from sklearn.metrics import mean_squared_error, r2_score # # MSE(mean squared erroe), R-square (모형 성능 확인)

# %%
# MSE 와 R-square 방법을 통해 정확도 평가 ; VIF가 높은 독립변수 3개 drop 하니 MSE, R-sqaure 값이 향상되었다.

mse = mean_squared_error(Y_test, Y_predict)  
rmse = np.sqrt(mse)
r_square = r2_score(Y_test, Y_predict)
print('MSE : {0:.3f}, RMSE : {1:.3f}'.format(mse, rmse))
print('R-square : {0:.3f}'.format(r_square))
# Out:
# MSE : 14.656, RMSE : 3.828
# R-square : 0.783

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor # VIF 확인을 위한 라이브러리 불러오기
from statsmodels.formula.api import ols

# %%
VIF_check = 'Life_expectancy ~ Status + Adult_mortality +  HepatitisB + Measles + BMI + Under_five_deaths + Polio + Diphtheria + HIV_AIDS + GDP + Population + Thinness_1_to_19_years + Income_composition_of_resources + Density'
VIF_check_ols = ols(VIF_check, data = who)
VIF_check_result = VIF_check_ols.fit()

pd.DataFrame({'Features': column, 'VIF': variance_inflation_factor(VIF_check_ols.exog, i)} 
             for i, column in enumerate(VIF_check_ols.exog_names)
             if column != 'Intercept')

# VIF 값이 확실히 줄었다.
# Out:
#                            Features       VIF
# 0                            Status  1.578767
# 1                   Adult_mortality  2.252778
# 2                        HepatitisB  6.439468
# 3                           Measles  2.663526
# 4                               BMI  1.710764
# 5                 Under_five_deaths  3.575224
# 6                             Polio  2.010938
# 7                        Diphtheria  7.708139
# 8                          HIV_AIDS  1.878591
# 9                               GDP  1.640260
# 10                       Population  1.301018
# 11           Thinness_1_to_19_years  2.016231
# 12  Income_composition_of_resources  3.077558
# 13                          Density  1.214979

# %%
# 산점도와 선형 회귀 그래프 (시각화)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axs = plt.subplots(figsize = (16, 30), ncols = 3, nrows = 5)
x_features = [ 'Status', 'Adult_mortality', 'HepatitisB', 'Measles', 'BMI', 'Under_five_deaths', 'Polio', 'Diphtheria', 'HIV_AIDS', 'GDP', 'Population', 'Thinness_1_to_19_years', 'Income_composition_of_resources', 'Density']
plot_color = ['r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g', 'r', 'b', 'y', 'g']
for i, feature in enumerate(x_features):
    row = int(i/3)
    col = i%3
    sns.regplot(x = feature, y = 'Life_expectancy', data = who, ax = axs[row][col], color = plot_color[i])

# %%
who.head()

# %%
hiv_aids_data = who['HIV_AIDS']
hiv_aids_data

# %%
Y_predict

# %%
print('국가의 정보를 입력해주세요.')

status_new = int(input('status: '))
Adult_mortality_new = int(input('Adult_mortality: '))
HepatitisB_new = int(input('HepatitisB: '))
Measles_new = int(input('Measles: '))
BMI_new = int(input('BMI: '))
Under_five_deaths_new = int(input('Under_five_deaths: '))
Polio_new = int(input('Polio: '))
Diphtheria_new = int(input('Diphtheria: '))
HIV_AIDS_new = float(input('HIV_AIDS: '))
GDP = int(input('GDP: '))
Population = int(input('Population: '))
Thinness_1_to_19_years = int(input('Thinness_1_to_19_years: '))
Schooling = int(input('Schooling: '))
Density = int(input('Density: '))

# %%
LE_predict = lm.predict([[status_new, Adult_mortality_new, HepatitisB_new, Measles_new, BMI_new, Under_five_deaths_new, Polio_new, Diphtheria_new, HIV_AIDS_new, GDP, Population, Thinness_1_to_19_years, Schooling, Density]])

# %%
print("이 국가의 기대 수명치는 %0.2f세 입니다." % LE_predict)
